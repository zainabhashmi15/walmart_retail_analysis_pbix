# %% [markdown]
# <a href="https://www.kaggle.com/code/zainabhashmi/walmart-retail-analysis?scriptVersionId=137385129" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ![image.png](attachment:9c4d1319-d54c-45a6-9f27-beca216611e0.png)

# %% [markdown]
# ![image.png](attachment:7f2e20a9-f024-472e-8fd4-c0115be1e600.png)

# %% [markdown]
# ![image.png](attachment:c398089b-bb4d-4ab1-8d75-e0a4ca0a8f81.png)

# %% [markdown]
# ![image.png](attachment:7d967ea0-6afc-446b-8cf1-711dd12b5d66.png)
